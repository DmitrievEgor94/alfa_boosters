# %%
import pandas as pd
import datetime

import seaborn as sns
sns.set(font_scale=1.3)

import catboost as cb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold


import numpy as np
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import f1_score, classification_report, confusion_matrix
import pickle

import warnings

from lightgbm import LGBMClassifier

warnings.filterwarnings("ignore")
# Out:
# /home/edmitrie/.local/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
SEED = 1

# %%
class_weight = {'card2card_transfer': 0.6398475182669389,
 'card_recharge': 0.4502000735911028,
 'chat': 0.3815013547758437,
 'credit_info': 0.46101125727352393,
 'invest': 0.9321761812255462,
 'main_screen': 0.982994897893273,
 'mobile_recharge': 0.641212783884727,
 'own_transfer': 0.6317591535575899,
 'phone_money_transfer': 0.4600662111029351,
 'statement': 0.6951657522904898}

# %%
train_df_less = pd.read_pickle('/data/edmitrie/alfa_boosters/train_df_less_ready.pickle')
test_df = pd.read_pickle('/data/edmitrie/alfa_boosters/test_df.pickle')

# %%
submit_df = pd.read_pickle('/data/edmitrie/alfa_boosters/submit_df.pickle')

# %%
cat_atrs = pickle.load(open('cat_atrs', 'rb'))
atrs = pickle.load(open('atrs', 'rb'))

# %% [markdown]
# ## Применение lgbm

# %%
def evalerror(y_true, y_pred):
    preds = np.reshape(y_pred, (y_true.shape[0], 10), order='F')
    preds = preds.argmax(axis = 1)
    f_score = f1_score(y_true, preds, average = 'macro')
    
    return 'f1_score', f_score, True

# %%
for cat_atr in cat_atrs:
#     train_df_less[cat_atr] = train_df_less[cat_atr].astype('category')
#     test_df[cat_atr] = test_df[cat_atr].astype('category')
#     train_df[cat_atr] = train_df[cat_atr].astype('category')
    submit_df[cat_atr] = submit_df[cat_atr].astype('category')

# %%
lgbm = LGBMClassifier(objective='multiclass', reg_alpha=12, max_depth=10, min_split_gain = 0.7, subsample=0.7, n_estimators=320, n_jobs=60, random_state=SEED)

# %%
cols_bigger = [atr for atr in atrs if 'bigger' in atr]

# %%
for col in cols_bigger:
    train_df_less[col] = train_df_less[col].astype(np.float32)
    test_df[col] = test_df[col].astype(np.float32)
#     train_df[col] = train_df[col].astype(np.float32)

# %%
atrs = [atr for atr in atrs if 'proba' not in atr or 'prev' in atr]

# %%
train_df_less.loc[train_df_less['timezone_num_prev_2'] == 'nan','timezone_num_prev_2'] = 0
train_df_less.loc[train_df_less['timezone_num_prev_1'] == 'nan','timezone_num_prev_1'] = 0

# %%
train_df_less['timezone_num_prev_2'] = train_df_less['timezone_num_prev_2'].astype(int)
train_df_less['timezone_num_prev_1'] = train_df_less['timezone_num_prev_1'].astype(int)

# %%
lgbm.fit(train_df_less[atrs], train_df_less['multi_class_target'], eval_set=(test_df[atrs], test_df['multi_class_target']), eval_metric=evalerror, verbose=20, early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 100 rounds
# [20]	valid_0's multi_logloss: 1.45094	valid_0's f1_score: 0.40638
# [40]	valid_0's multi_logloss: 1.43375	valid_0's f1_score: 0.40599
# [60]	valid_0's multi_logloss: 1.42871	valid_0's f1_score: 0.407418
# [80]	valid_0's multi_logloss: 1.42688	valid_0's f1_score: 0.408683
# [100]	valid_0's multi_logloss: 1.42505	valid_0's f1_score: 0.409115
# [120]	valid_0's multi_logloss: 1.42398	valid_0's f1_score: 0.410432
# [140]	valid_0's multi_logloss: 1.42311	valid_0's f1_score: 0.409683
# [160]	valid_0's multi_logloss: 1.4231	valid_0's f1_score: 0.410029
# [180]	valid_0's multi_logloss: 1.42312	valid_0's f1_score: 0.41006
# [200]	valid_0's multi_logloss: 1.42251	valid_0's f1_score: 0.409579
# [220]	valid_0's multi_logloss: 1.42221	valid_0's f1_score: 0.409973
# [240]	valid_0's multi_logloss: 1.4225	valid_0's f1_score: 0.410764
# [260]	valid_0's multi_logloss: 1.42219	valid_0's f1_score: 0.410813
# [280]	valid_0's multi_logloss: 1.42183	valid_0's f1_score: 0.410059
# [300]	valid_0's multi_logloss: 1.42169	valid_0's f1_score: 0.410143
# [320]	valid_0's multi_logloss: 1.42185	valid_0's f1_score: 0.410216
# Did not meet early stopping. Best iteration is:
# [297]	valid_0's multi_logloss: 1.42168	valid_0's f1_score: 0.410379
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=10,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.7,
#                n_estimators=320, n_jobs=60, num_leaves=31,
#                objective='multiclass', random_state=1, reg_alpha=12,
#                reg_lambda=0.0, silent=True, subsample=0.7,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
def get_new_features(df):
        for i in range(df.shape[0]):
            if df['im'].iloc[:i].sum()/df['im'].sum() > 0.99:
                break
        return df['f'].iloc[:i].values.tolist()

# %%
f_imp = pd.DataFrame(zip(lgbm.feature_name_, lgbm.feature_importances_), columns=['f', 'im']).sort_values(by='im', ascending=False)

# %%
new_atrs = get_new_features(f_imp)

# %%
lgbm = LGBMClassifier(objective='multiclass', reg_alpha=12, max_depth=10, min_split_gain = 0.7, subsample=0.7, n_estimators=320, n_jobs=60, random_state=SEED, class_weight=class_weight)

# %%
lgbm.fit(train_df_less[new_atrs], train_df_less['multi_class_target'], eval_set=(test_df[new_atrs], test_df['multi_class_target']), eval_metric=evalerror, verbose=5, early_stopping_rounds=100)
# Out:
# Training until validation scores don't improve for 100 rounds
# [5]	valid_0's multi_logloss: 1.53466	valid_0's f1_score: 0.352629
# [10]	valid_0's multi_logloss: 1.43285	valid_0's f1_score: 0.390188
# [15]	valid_0's multi_logloss: 1.39226	valid_0's f1_score: 0.399601
# [20]	valid_0's multi_logloss: 1.37346	valid_0's f1_score: 0.405104
# [25]	valid_0's multi_logloss: 1.36429	valid_0's f1_score: 0.407788
# [30]	valid_0's multi_logloss: 1.35893	valid_0's f1_score: 0.409097
# [35]	valid_0's multi_logloss: 1.35745	valid_0's f1_score: 0.410357
# [40]	valid_0's multi_logloss: 1.35549	valid_0's f1_score: 0.411354
# [45]	valid_0's multi_logloss: 1.35358	valid_0's f1_score: 0.411935
# [50]	valid_0's multi_logloss: 1.3523	valid_0's f1_score: 0.412762
# [55]	valid_0's multi_logloss: 1.35132	valid_0's f1_score: 0.413338
# [60]	valid_0's multi_logloss: 1.35075	valid_0's f1_score: 0.414003
# [65]	valid_0's multi_logloss: 1.35024	valid_0's f1_score: 0.413719
# [70]	valid_0's multi_logloss: 1.34942	valid_0's f1_score: 0.414253
# [75]	valid_0's multi_logloss: 1.34884	valid_0's f1_score: 0.414136
# [80]	valid_0's multi_logloss: 1.34807	valid_0's f1_score: 0.414151
# [85]	valid_0's multi_logloss: 1.34764	valid_0's f1_score: 0.413851
# [90]	valid_0's multi_logloss: 1.34703	valid_0's f1_score: 0.413866
# [95]	valid_0's multi_logloss: 1.34623	valid_0's f1_score: 0.414092
# [100]	valid_0's multi_logloss: 1.3461	valid_0's f1_score: 0.414582
# [105]	valid_0's multi_logloss: 1.34569	valid_0's f1_score: 0.414278
# [110]	valid_0's multi_logloss: 1.34551	valid_0's f1_score: 0.413852
# [115]	valid_0's multi_logloss: 1.34519	valid_0's f1_score: 0.414224
# [120]	valid_0's multi_logloss: 1.34566	valid_0's f1_score: 0.414769
# [125]	valid_0's multi_logloss: 1.34563	valid_0's f1_score: 0.414713
# [130]	valid_0's multi_logloss: 1.34547	valid_0's f1_score: 0.414813
# [135]	valid_0's multi_logloss: 1.34512	valid_0's f1_score: 0.415306
# [140]	valid_0's multi_logloss: 1.34514	valid_0's f1_score: 0.415056
# [145]	valid_0's multi_logloss: 1.34489	valid_0's f1_score: 0.415031
# [150]	valid_0's multi_logloss: 1.34543	valid_0's f1_score: 0.415432
# [155]	valid_0's multi_logloss: 1.34561	valid_0's f1_score: 0.415107
# [160]	valid_0's multi_logloss: 1.34542	valid_0's f1_score: 0.415176
# [165]	valid_0's multi_logloss: 1.34546	valid_0's f1_score: 0.415236
# [170]	valid_0's multi_logloss: 1.34543	valid_0's f1_score: 0.415231
# [175]	valid_0's multi_logloss: 1.34512	valid_0's f1_score: 0.415618
# [180]	valid_0's multi_logloss: 1.34511	valid_0's f1_score: 0.415509
# [185]	valid_0's multi_logloss: 1.34519	valid_0's f1_score: 0.415413
# [190]	valid_0's multi_logloss: 1.34527	valid_0's f1_score: 0.415257
# [195]	valid_0's multi_logloss: 1.34564	valid_0's f1_score: 0.415119
# [200]	valid_0's multi_logloss: 1.3455	valid_0's f1_score: 0.415081
# [205]	valid_0's multi_logloss: 1.34567	valid_0's f1_score: 0.415117
# [210]	valid_0's multi_logloss: 1.34577	valid_0's f1_score: 0.415329
# [215]	valid_0's multi_logloss: 1.34583	valid_0's f1_score: 0.415126
# [220]	valid_0's multi_logloss: 1.34578	valid_0's f1_score: 0.415184
# [225]	valid_0's multi_logloss: 1.34584	valid_0's f1_score: 0.415466
# [230]	valid_0's multi_logloss: 1.3459	valid_0's f1_score: 0.415191
# [235]	valid_0's multi_logloss: 1.34601	valid_0's f1_score: 0.415463
# [240]	valid_0's multi_logloss: 1.3462	valid_0's f1_score: 0.415604
# [245]	valid_0's multi_logloss: 1.34628	valid_0's f1_score: 0.415525
# Early stopping, best iteration is:
# [145]	valid_0's multi_logloss: 1.34489	valid_0's f1_score: 0.415031
# LGBMClassifier(boosting_type='gbdt',
#                class_weight={'card2card_transfer': 0.6398475182669389,
#                              'card_recharge': 0.4502000735911028,
#                              'chat': 0.3815013547758437,
#                              'credit_info': 0.46101125727352393,
#                              'invest': 0.9321761812255462,
#                              'main_screen': 0.982994897893273,
#                              'mobile_recharge': 0.641212783884727,
#                              'own_transfer': 0.6317591535575899,
#                              'phone_money_transfer': 0.4600662111029351,
#                              'statement': 0.6951657522904898},
#                colsample_bytree=1.0, importance_type='split', learning_rate=0.1,
#                max_depth=10, min_child_samples=20, min_child_weight=0.001,
#                min_split_gain=0.7, n_estimators=320, n_jobs=60, num_leaves=31,
#                objective='multiclass', random_state=1, reg_alpha=12,
#                reg_lambda=0.0, silent=True, subsample=0.7,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
def blending_lgbm(model, metric, X, y, X_eval, y_eval):
    k_fold = StratifiedKFold(5, shuffle=True, random_state=SEED)
    metrics = []
    models = []

    for train_ind, test_ind in k_fold.split(X, y):
        X_train, X_test = X.iloc[train_ind], X.iloc[test_ind]
        y_train, y_test = y.iloc[train_ind], y.iloc[test_ind]
        
        model = LGBMClassifier(objective='multiclass', class_weight=class_weight, reg_alpha=12, max_depth=10, min_split_gain = 0.7, subsample=0.7, n_estimators=250, n_jobs=60, random_state=SEED)

        model.fit(X_train, y_train, eval_set = (X_eval, y_eval), eval_metric=evalerror, early_stopping_rounds=100)
        models.append(model)

        metrics.append(metric(y_eval, model.predict(X_eval), average='macro'))
        print(metrics[-1])

    return models, metrics

# %%
models, metrics = blending_lgbm(lgbm, f1_score, train_df_less[new_atrs], train_df_less['multi_class_target'], test_df[new_atrs], test_df['multi_class_target'])
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	valid_0's multi_logloss: 1.76398	valid_0's f1_score: 0.0895974
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 1.67971	valid_0's f1_score: 0.188234
# [3]	valid_0's multi_logloss: 1.61869	valid_0's f1_score: 0.275309
# [4]	valid_0's multi_logloss: 1.57248	valid_0's f1_score: 0.326217
# [5]	valid_0's multi_logloss: 1.5361	valid_0's f1_score: 0.348786
# [6]	valid_0's multi_logloss: 1.50662	valid_0's f1_score: 0.363021
# [7]	valid_0's multi_logloss: 1.48293	valid_0's f1_score: 0.372218
# [8]	valid_0's multi_logloss: 1.46342	valid_0's f1_score: 0.379172
# [9]	valid_0's multi_logloss: 1.44771	valid_0's f1_score: 0.384937
# [10]	valid_0's multi_logloss: 1.43443	valid_0's f1_score: 0.389058
# [11]	valid_0's multi_logloss: 1.4236	valid_0's f1_score: 0.390965
# [12]	valid_0's multi_logloss: 1.41443	valid_0's f1_score: 0.393226
# [13]	valid_0's multi_logloss: 1.40657	valid_0's f1_score: 0.395367
# [14]	valid_0's multi_logloss: 1.39962	valid_0's f1_score: 0.39805
# [15]	valid_0's multi_logloss: 1.39418	valid_0's f1_score: 0.399716
# [16]	valid_0's multi_logloss: 1.38918	valid_0's f1_score: 0.400753
# [17]	valid_0's multi_logloss: 1.38487	valid_0's f1_score: 0.400997
# [18]	valid_0's multi_logloss: 1.38096	valid_0's f1_score: 0.40241
# [19]	valid_0's multi_logloss: 1.37768	valid_0's f1_score: 0.402956
# [20]	valid_0's multi_logloss: 1.3758	valid_0's f1_score: 0.402876
# [21]	valid_0's multi_logloss: 1.37362	valid_0's f1_score: 0.403893
# [22]	valid_0's multi_logloss: 1.37202	valid_0's f1_score: 0.404484
# [23]	valid_0's multi_logloss: 1.36976	valid_0's f1_score: 0.40501
# [24]	valid_0's multi_logloss: 1.36787	valid_0's f1_score: 0.405361
# [25]	valid_0's multi_logloss: 1.36618	valid_0's f1_score: 0.40583
# [26]	valid_0's multi_logloss: 1.36612	valid_0's f1_score: 0.406471
# [27]	valid_0's multi_logloss: 1.36481	valid_0's f1_score: 0.405967
# [28]	valid_0's multi_logloss: 1.36351	valid_0's f1_score: 0.406471
# [29]	valid_0's multi_logloss: 1.36228	valid_0's f1_score: 0.407224
# [30]	valid_0's multi_logloss: 1.36309	valid_0's f1_score: 0.407449
# [31]	valid_0's multi_logloss: 1.36228	valid_0's f1_score: 0.407704
# [32]	valid_0's multi_logloss: 1.36143	valid_0's f1_score: 0.407764
# [33]	valid_0's multi_logloss: 1.36053	valid_0's f1_score: 0.408256
# [34]	valid_0's multi_logloss: 1.35995	valid_0's f1_score: 0.408679
# [35]	valid_0's multi_logloss: 1.3591	valid_0's f1_score: 0.408951
# [36]	valid_0's multi_logloss: 1.35844	valid_0's f1_score: 0.409166
# [37]	valid_0's multi_logloss: 1.35789	valid_0's f1_score: 0.409411
# [38]	valid_0's multi_logloss: 1.35761	valid_0's f1_score: 0.40924
# [39]	valid_0's multi_logloss: 1.35716	valid_0's f1_score: 0.409206
# [40]	valid_0's multi_logloss: 1.35649	valid_0's f1_score: 0.409446
# [41]	valid_0's multi_logloss: 1.35618	valid_0's f1_score: 0.409719
# [42]	valid_0's multi_logloss: 1.35584	valid_0's f1_score: 0.409831
# [43]	valid_0's multi_logloss: 1.35531	valid_0's f1_score: 0.409725
# [44]	valid_0's multi_logloss: 1.35509	valid_0's f1_score: 0.409885
# [45]	valid_0's multi_logloss: 1.3548	valid_0's f1_score: 0.41027
# [46]	valid_0's multi_logloss: 1.35439	valid_0's f1_score: 0.410086
# [47]	valid_0's multi_logloss: 1.35418	valid_0's f1_score: 0.41028
# [48]	valid_0's multi_logloss: 1.35409	valid_0's f1_score: 0.410387
# [49]	valid_0's multi_logloss: 1.35394	valid_0's f1_score: 0.410154
# [50]	valid_0's multi_logloss: 1.3537	valid_0's f1_score: 0.410147
# [51]	valid_0's multi_logloss: 1.35333	valid_0's f1_score: 0.41031
# [52]	valid_0's multi_logloss: 1.35323	valid_0's f1_score: 0.410533
# [53]	valid_0's multi_logloss: 1.35307	valid_0's f1_score: 0.410899
# [54]	valid_0's multi_logloss: 1.35282	valid_0's f1_score: 0.410794
# [55]	valid_0's multi_logloss: 1.35252	valid_0's f1_score: 0.411095
# [56]	valid_0's multi_logloss: 1.35253	valid_0's f1_score: 0.411265
# [57]	valid_0's multi_logloss: 1.35236	valid_0's f1_score: 0.411202
# [58]	valid_0's multi_logloss: 1.35222	valid_0's f1_score: 0.411329
# [59]	valid_0's multi_logloss: 1.35239	valid_0's f1_score: 0.411217
# [60]	valid_0's multi_logloss: 1.35221	valid_0's f1_score: 0.41108
# [61]	valid_0's multi_logloss: 1.35202	valid_0's f1_score: 0.410818
# [62]	valid_0's multi_logloss: 1.35179	valid_0's f1_score: 0.410987
# [63]	valid_0's multi_logloss: 1.35187	valid_0's f1_score: 0.41101
# [64]	valid_0's multi_logloss: 1.3515	valid_0's f1_score: 0.411315
# [65]	valid_0's multi_logloss: 1.35146	valid_0's f1_score: 0.41163
# [66]	valid_0's multi_logloss: 1.35115	valid_0's f1_score: 0.411329
# [67]	valid_0's multi_logloss: 1.35103	valid_0's f1_score: 0.411371
# [68]	valid_0's multi_logloss: 1.35084	valid_0's f1_score: 0.411542
# [69]	valid_0's multi_logloss: 1.35055	valid_0's f1_score: 0.411802
# [70]	valid_0's multi_logloss: 1.35017	valid_0's f1_score: 0.411492
# [71]	valid_0's multi_logloss: 1.35018	valid_0's f1_score: 0.411556
# [72]	valid_0's multi_logloss: 1.35013	valid_0's f1_score: 0.411791
# [73]	valid_0's multi_logloss: 1.34994	valid_0's f1_score: 0.411464
# [74]	valid_0's multi_logloss: 1.3502	valid_0's f1_score: 0.412093
# [75]	valid_0's multi_logloss: 1.35002	valid_0's f1_score: 0.412306
# [76]	valid_0's multi_logloss: 1.3498	valid_0's f1_score: 0.412118
# [77]	valid_0's multi_logloss: 1.34966	valid_0's f1_score: 0.412097
# [78]	valid_0's multi_logloss: 1.34953	valid_0's f1_score: 0.412155
# [79]	valid_0's multi_logloss: 1.34927	valid_0's f1_score: 0.412366
# [80]	valid_0's multi_logloss: 1.34925	valid_0's f1_score: 0.412549
# [81]	valid_0's multi_logloss: 1.34921	valid_0's f1_score: 0.412549
# [82]	valid_0's multi_logloss: 1.3492	valid_0's f1_score: 0.412419
# [83]	valid_0's multi_logloss: 1.34927	valid_0's f1_score: 0.412426
# [84]	valid_0's multi_logloss: 1.34924	valid_0's f1_score: 0.412427
# [85]	valid_0's multi_logloss: 1.34917	valid_0's f1_score: 0.412496
# [86]	valid_0's multi_logloss: 1.34911	valid_0's f1_score: 0.412468
# [87]	valid_0's multi_logloss: 1.34895	valid_0's f1_score: 0.412593
# [88]	valid_0's multi_logloss: 1.34901	valid_0's f1_score: 0.412374
# [89]	valid_0's multi_logloss: 1.34894	valid_0's f1_score: 0.412606
# [90]	valid_0's multi_logloss: 1.34896	valid_0's f1_score: 0.412598
# [91]	valid_0's multi_logloss: 1.34921	valid_0's f1_score: 0.412416
# [92]	valid_0's multi_logloss: 1.34933	valid_0's f1_score: 0.41223
# [93]	valid_0's multi_logloss: 1.34922	valid_0's f1_score: 0.41206
# [94]	valid_0's multi_logloss: 1.34925	valid_0's f1_score: 0.412166
# [95]	valid_0's multi_logloss: 1.34908	valid_0's f1_score: 0.41192
# [96]	valid_0's multi_logloss: 1.34908	valid_0's f1_score: 0.412018
# [97]	valid_0's multi_logloss: 1.34911	valid_0's f1_score: 0.411856
# [98]	valid_0's multi_logloss: 1.34913	valid_0's f1_score: 0.411878
# [99]	valid_0's multi_logloss: 1.34916	valid_0's f1_score: 0.411831
# [100]	valid_0's multi_logloss: 1.3492	valid_0's f1_score: 0.411678
# [101]	valid_0's multi_logloss: 1.34894	valid_0's f1_score: 0.412076
# [102]	valid_0's multi_logloss: 1.34889	valid_0's f1_score: 0.411771
# [103]	valid_0's multi_logloss: 1.34897	valid_0's f1_score: 0.411472
# [104]	valid_0's multi_logloss: 1.34897	valid_0's f1_score: 0.411974
# [105]	valid_0's multi_logloss: 1.34898	valid_0's f1_score: 0.412115
# [106]	valid_0's multi_logloss: 1.349	valid_0's f1_score: 0.41217
# [107]	valid_0's multi_logloss: 1.34902	valid_0's f1_score: 0.4122
# [108]	valid_0's multi_logloss: 1.34879	valid_0's f1_score: 0.41226
# [109]	valid_0's multi_logloss: 1.34883	valid_0's f1_score: 0.41221
# [110]	valid_0's multi_logloss: 1.34865	valid_0's f1_score: 0.41232
# [111]	valid_0's multi_logloss: 1.34867	valid_0's f1_score: 0.412285
# [112]	valid_0's multi_logloss: 1.34856	valid_0's f1_score: 0.411996
# [113]	valid_0's multi_logloss: 1.34859	valid_0's f1_score: 0.412036
# [114]	valid_0's multi_logloss: 1.34842	valid_0's f1_score: 0.412225
# [115]	valid_0's multi_logloss: 1.34827	valid_0's f1_score: 0.411923
# [116]	valid_0's multi_logloss: 1.34834	valid_0's f1_score: 0.412467
# [117]	valid_0's multi_logloss: 1.34831	valid_0's f1_score: 0.412271
# [118]	valid_0's multi_logloss: 1.34837	valid_0's f1_score: 0.412153
# [119]	valid_0's multi_logloss: 1.34858	valid_0's f1_score: 0.412221
# [120]	valid_0's multi_logloss: 1.34859	valid_0's f1_score: 0.412126
# [121]	valid_0's multi_logloss: 1.34869	valid_0's f1_score: 0.411959
# [122]	valid_0's multi_logloss: 1.34869	valid_0's f1_score: 0.411837
# [123]	valid_0's multi_logloss: 1.34867	valid_0's f1_score: 0.411596
# [124]	valid_0's multi_logloss: 1.34848	valid_0's f1_score: 0.411894
# [125]	valid_0's multi_logloss: 1.34854	valid_0's f1_score: 0.411934
# [126]	valid_0's multi_logloss: 1.34868	valid_0's f1_score: 0.411724
# [127]	valid_0's multi_logloss: 1.34858	valid_0's f1_score: 0.412032
# [128]	valid_0's multi_logloss: 1.34861	valid_0's f1_score: 0.412237
# [129]	valid_0's multi_logloss: 1.3487	valid_0's f1_score: 0.412208
# [130]	valid_0's multi_logloss: 1.3488	valid_0's f1_score: 0.411904
# [131]	valid_0's multi_logloss: 1.34869	valid_0's f1_score: 0.412009
# [132]	valid_0's multi_logloss: 1.3486	valid_0's f1_score: 0.412165
# [133]	valid_0's multi_logloss: 1.34863	valid_0's f1_score: 0.412177
# [134]	valid_0's multi_logloss: 1.34864	valid_0's f1_score: 0.412229
# [135]	valid_0's multi_logloss: 1.34837	valid_0's f1_score: 0.412123
# [136]	valid_0's multi_logloss: 1.34831	valid_0's f1_score: 0.412204
# [137]	valid_0's multi_logloss: 1.34818	valid_0's f1_score: 0.412298
# [138]	valid_0's multi_logloss: 1.34825	valid_0's f1_score: 0.412118
# [139]	valid_0's multi_logloss: 1.34825	valid_0's f1_score: 0.412081
# [140]	valid_0's multi_logloss: 1.34815	valid_0's f1_score: 0.412146
# [141]	valid_0's multi_logloss: 1.34811	valid_0's f1_score: 0.411714
# [142]	valid_0's multi_logloss: 1.34795	valid_0's f1_score: 0.411912
# [143]	valid_0's multi_logloss: 1.34794	valid_0's f1_score: 0.411778
# [144]	valid_0's multi_logloss: 1.34828	valid_0's f1_score: 0.411765
# [145]	valid_0's multi_logloss: 1.34827	valid_0's f1_score: 0.411573
# [146]	valid_0's multi_logloss: 1.3483	valid_0's f1_score: 0.411791
# [147]	valid_0's multi_logloss: 1.34834	valid_0's f1_score: 0.411621
# [148]	valid_0's multi_logloss: 1.34837	valid_0's f1_score: 0.411865
# [149]	valid_0's multi_logloss: 1.34856	valid_0's f1_score: 0.411737
# [150]	valid_0's multi_logloss: 1.34855	valid_0's f1_score: 0.41166
# [151]	valid_0's multi_logloss: 1.34867	valid_0's f1_score: 0.411654
# [152]	valid_0's multi_logloss: 1.34864	valid_0's f1_score: 0.411818
# [153]	valid_0's multi_logloss: 1.3486	valid_0's f1_score: 0.411517
# [154]	valid_0's multi_logloss: 1.34856	valid_0's f1_score: 0.411385
# [155]	valid_0's multi_logloss: 1.34861	valid_0's f1_score: 0.411392
# [156]	valid_0's multi_logloss: 1.34854	valid_0's f1_score: 0.411385
# [157]	valid_0's multi_logloss: 1.3485	valid_0's f1_score: 0.411232
# [158]	valid_0's multi_logloss: 1.34849	valid_0's f1_score: 0.411137
# [159]	valid_0's multi_logloss: 1.34847	valid_0's f1_score: 0.411399
# [160]	valid_0's multi_logloss: 1.34848	valid_0's f1_score: 0.411365
# [161]	valid_0's multi_logloss: 1.34872	valid_0's f1_score: 0.411425
# [162]	valid_0's multi_logloss: 1.34869	valid_0's f1_score: 0.411391
# [163]	valid_0's multi_logloss: 1.34863	valid_0's f1_score: 0.411305
# [164]	valid_0's multi_logloss: 1.34853	valid_0's f1_score: 0.411333
# [165]	valid_0's multi_logloss: 1.3485	valid_0's f1_score: 0.41127
# [166]	valid_0's multi_logloss: 1.34851	valid_0's f1_score: 0.411421
# [167]	valid_0's multi_logloss: 1.34848	valid_0's f1_score: 0.411447
# [168]	valid_0's multi_logloss: 1.34847	valid_0's f1_score: 0.411585
# [169]	valid_0's multi_logloss: 1.34855	valid_0's f1_score: 0.411723
# [170]	valid_0's multi_logloss: 1.3487	valid_0's f1_score: 0.411606
# [171]	valid_0's multi_logloss: 1.34874	valid_0's f1_score: 0.411681
# [172]	valid_0's multi_logloss: 1.34876	valid_0's f1_score: 0.411764
# [173]	valid_0's multi_logloss: 1.34869	valid_0's f1_score: 0.411752
# [174]	valid_0's multi_logloss: 1.34868	valid_0's f1_score: 0.411844
# [175]	valid_0's multi_logloss: 1.34872	valid_0's f1_score: 0.411854
# [176]	valid_0's multi_logloss: 1.34873	valid_0's f1_score: 0.411678
# [177]	valid_0's multi_logloss: 1.3488	valid_0's f1_score: 0.411728
# [178]	valid_0's multi_logloss: 1.34881	valid_0's f1_score: 0.411764
# [179]	valid_0's multi_logloss: 1.34881	valid_0's f1_score: 0.411572
# [180]	valid_0's multi_logloss: 1.34877	valid_0's f1_score: 0.411599
# [181]	valid_0's multi_logloss: 1.34888	valid_0's f1_score: 0.411511
# [182]	valid_0's multi_logloss: 1.34885	valid_0's f1_score: 0.411566
# [183]	valid_0's multi_logloss: 1.3489	valid_0's f1_score: 0.411451
# [184]	valid_0's multi_logloss: 1.34894	valid_0's f1_score: 0.411519
# [185]	valid_0's multi_logloss: 1.34899	valid_0's f1_score: 0.411531
# [186]	valid_0's multi_logloss: 1.34887	valid_0's f1_score: 0.411432
# [187]	valid_0's multi_logloss: 1.3489	valid_0's f1_score: 0.411309
# [188]	valid_0's multi_logloss: 1.34885	valid_0's f1_score: 0.41137
# [189]	valid_0's multi_logloss: 1.34887	valid_0's f1_score: 0.411321
# Early stopping, best iteration is:
# [89]	valid_0's multi_logloss: 1.34894	valid_0's f1_score: 0.412606
# 0.4126057202437262
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	valid_0's multi_logloss: 1.76354	valid_0's f1_score: 0.0877955
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 1.67947	valid_0's f1_score: 0.187428
# [3]	valid_0's multi_logloss: 1.61849	valid_0's f1_score: 0.281699
# [4]	valid_0's multi_logloss: 1.57245	valid_0's f1_score: 0.3242
# [5]	valid_0's multi_logloss: 1.53605	valid_0's f1_score: 0.348784
# [6]	valid_0's multi_logloss: 1.50647	valid_0's f1_score: 0.364687
# [7]	valid_0's multi_logloss: 1.48293	valid_0's f1_score: 0.373567
# [8]	valid_0's multi_logloss: 1.46333	valid_0's f1_score: 0.380968
# [9]	valid_0's multi_logloss: 1.4472	valid_0's f1_score: 0.386055
# [10]	valid_0's multi_logloss: 1.43409	valid_0's f1_score: 0.390093
# [11]	valid_0's multi_logloss: 1.42267	valid_0's f1_score: 0.392674
# [12]	valid_0's multi_logloss: 1.41352	valid_0's f1_score: 0.39486
# [13]	valid_0's multi_logloss: 1.4054	valid_0's f1_score: 0.396911
# [14]	valid_0's multi_logloss: 1.39851	valid_0's f1_score: 0.398561
# [15]	valid_0's multi_logloss: 1.39369	valid_0's f1_score: 0.40004
# [16]	valid_0's multi_logloss: 1.38851	valid_0's f1_score: 0.401595
# [17]	valid_0's multi_logloss: 1.38444	valid_0's f1_score: 0.402712
# [18]	valid_0's multi_logloss: 1.3807	valid_0's f1_score: 0.403471
# [19]	valid_0's multi_logloss: 1.37768	valid_0's f1_score: 0.404258
# [20]	valid_0's multi_logloss: 1.37462	valid_0's f1_score: 0.40512
# [21]	valid_0's multi_logloss: 1.3717	valid_0's f1_score: 0.405725
# [22]	valid_0's multi_logloss: 1.36926	valid_0's f1_score: 0.406638
# [23]	valid_0's multi_logloss: 1.36725	valid_0's f1_score: 0.406734
# [24]	valid_0's multi_logloss: 1.36537	valid_0's f1_score: 0.407827
# [25]	valid_0's multi_logloss: 1.36384	valid_0's f1_score: 0.408265
# [26]	valid_0's multi_logloss: 1.3623	valid_0's f1_score: 0.408609
# [27]	valid_0's multi_logloss: 1.36092	valid_0's f1_score: 0.408843
# [28]	valid_0's multi_logloss: 1.3598	valid_0's f1_score: 0.409492
# [29]	valid_0's multi_logloss: 1.35879	valid_0's f1_score: 0.409282
# [30]	valid_0's multi_logloss: 1.35754	valid_0's f1_score: 0.409369
# [31]	valid_0's multi_logloss: 1.35721	valid_0's f1_score: 0.409482
# [32]	valid_0's multi_logloss: 1.35634	valid_0's f1_score: 0.409845
# [33]	valid_0's multi_logloss: 1.35551	valid_0's f1_score: 0.410035
# [34]	valid_0's multi_logloss: 1.3547	valid_0's f1_score: 0.41016
# [35]	valid_0's multi_logloss: 1.35422	valid_0's f1_score: 0.410205
# [36]	valid_0's multi_logloss: 1.35373	valid_0's f1_score: 0.410563
# [37]	valid_0's multi_logloss: 1.35333	valid_0's f1_score: 0.410715
# [38]	valid_0's multi_logloss: 1.35259	valid_0's f1_score: 0.410874
# [39]	valid_0's multi_logloss: 1.35202	valid_0's f1_score: 0.411114
# [40]	valid_0's multi_logloss: 1.35167	valid_0's f1_score: 0.410843
# [41]	valid_0's multi_logloss: 1.35128	valid_0's f1_score: 0.410757
# [42]	valid_0's multi_logloss: 1.35105	valid_0's f1_score: 0.410802
# [43]	valid_0's multi_logloss: 1.35073	valid_0's f1_score: 0.411114
# [44]	valid_0's multi_logloss: 1.35045	valid_0's f1_score: 0.411164
# [45]	valid_0's multi_logloss: 1.35003	valid_0's f1_score: 0.411104
# [46]	valid_0's multi_logloss: 1.34972	valid_0's f1_score: 0.410878
# [47]	valid_0's multi_logloss: 1.34918	valid_0's f1_score: 0.411145
# [48]	valid_0's multi_logloss: 1.349	valid_0's f1_score: 0.411349
# [49]	valid_0's multi_logloss: 1.34889	valid_0's f1_score: 0.411438
# [50]	valid_0's multi_logloss: 1.34847	valid_0's f1_score: 0.412152
# [51]	valid_0's multi_logloss: 1.34829	valid_0's f1_score: 0.412173
# [52]	valid_0's multi_logloss: 1.348	valid_0's f1_score: 0.411877
# [53]	valid_0's multi_logloss: 1.34784	valid_0's f1_score: 0.412382
# [54]	valid_0's multi_logloss: 1.34759	valid_0's f1_score: 0.412274
# [55]	valid_0's multi_logloss: 1.34769	valid_0's f1_score: 0.412253
# [56]	valid_0's multi_logloss: 1.3473	valid_0's f1_score: 0.41207
# [57]	valid_0's multi_logloss: 1.34703	valid_0's f1_score: 0.412478
# [58]	valid_0's multi_logloss: 1.3469	valid_0's f1_score: 0.412864
# [59]	valid_0's multi_logloss: 1.34649	valid_0's f1_score: 0.413054
# [60]	valid_0's multi_logloss: 1.34636	valid_0's f1_score: 0.413112
# [61]	valid_0's multi_logloss: 1.34628	valid_0's f1_score: 0.413584
# [62]	valid_0's multi_logloss: 1.34625	valid_0's f1_score: 0.413382
# [63]	valid_0's multi_logloss: 1.3462	valid_0's f1_score: 0.413045
# [64]	valid_0's multi_logloss: 1.34626	valid_0's f1_score: 0.413871
# [65]	valid_0's multi_logloss: 1.3459	valid_0's f1_score: 0.413856
# [66]	valid_0's multi_logloss: 1.34593	valid_0's f1_score: 0.413867
# [67]	valid_0's multi_logloss: 1.34602	valid_0's f1_score: 0.413566
# [68]	valid_0's multi_logloss: 1.34592	valid_0's f1_score: 0.413408
# [69]	valid_0's multi_logloss: 1.34583	valid_0's f1_score: 0.413434
# [70]	valid_0's multi_logloss: 1.34575	valid_0's f1_score: 0.413194
# [71]	valid_0's multi_logloss: 1.34552	valid_0's f1_score: 0.413541
# [72]	valid_0's multi_logloss: 1.34558	valid_0's f1_score: 0.413089
# [73]	valid_0's multi_logloss: 1.34559	valid_0's f1_score: 0.412873
# [74]	valid_0's multi_logloss: 1.34549	valid_0's f1_score: 0.41279
# [75]	valid_0's multi_logloss: 1.34543	valid_0's f1_score: 0.413112
# [76]	valid_0's multi_logloss: 1.34534	valid_0's f1_score: 0.413077
# [77]	valid_0's multi_logloss: 1.34532	valid_0's f1_score: 0.413082
# [78]	valid_0's multi_logloss: 1.34531	valid_0's f1_score: 0.412921
# [79]	valid_0's multi_logloss: 1.34485	valid_0's f1_score: 0.412755
# [80]	valid_0's multi_logloss: 1.34477	valid_0's f1_score: 0.413148
# [81]	valid_0's multi_logloss: 1.34465	valid_0's f1_score: 0.413303
# [82]	valid_0's multi_logloss: 1.34448	valid_0's f1_score: 0.41328
# [83]	valid_0's multi_logloss: 1.34444	valid_0's f1_score: 0.413384
# [84]	valid_0's multi_logloss: 1.34432	valid_0's f1_score: 0.41338
# [85]	valid_0's multi_logloss: 1.3441	valid_0's f1_score: 0.413419
# [86]	valid_0's multi_logloss: 1.34401	valid_0's f1_score: 0.413718
# [87]	valid_0's multi_logloss: 1.34411	valid_0's f1_score: 0.413276
# [88]	valid_0's multi_logloss: 1.34405	valid_0's f1_score: 0.413214
# [89]	valid_0's multi_logloss: 1.34406	valid_0's f1_score: 0.413147
# [90]	valid_0's multi_logloss: 1.34398	valid_0's f1_score: 0.413347
# [91]	valid_0's multi_logloss: 1.34394	valid_0's f1_score: 0.4137
# [92]	valid_0's multi_logloss: 1.34384	valid_0's f1_score: 0.413756
# [93]	valid_0's multi_logloss: 1.34362	valid_0's f1_score: 0.413413
# [94]	valid_0's multi_logloss: 1.34371	valid_0's f1_score: 0.413598
# [95]	valid_0's multi_logloss: 1.34375	valid_0's f1_score: 0.413529
# [96]	valid_0's multi_logloss: 1.34362	valid_0's f1_score: 0.413317
# [97]	valid_0's multi_logloss: 1.34366	valid_0's f1_score: 0.413482
# [98]	valid_0's multi_logloss: 1.34347	valid_0's f1_score: 0.413547
# [99]	valid_0's multi_logloss: 1.34322	valid_0's f1_score: 0.413654
# [100]	valid_0's multi_logloss: 1.34309	valid_0's f1_score: 0.413821
# [101]	valid_0's multi_logloss: 1.34304	valid_0's f1_score: 0.413882
# [102]	valid_0's multi_logloss: 1.34301	valid_0's f1_score: 0.414057
# [103]	valid_0's multi_logloss: 1.34299	valid_0's f1_score: 0.414059
# [104]	valid_0's multi_logloss: 1.34314	valid_0's f1_score: 0.413623
# [105]	valid_0's multi_logloss: 1.34317	valid_0's f1_score: 0.413545
# [106]	valid_0's multi_logloss: 1.34346	valid_0's f1_score: 0.413361
# [107]	valid_0's multi_logloss: 1.34346	valid_0's f1_score: 0.413611
# [108]	valid_0's multi_logloss: 1.34358	valid_0's f1_score: 0.413862
# [109]	valid_0's multi_logloss: 1.34335	valid_0's f1_score: 0.414133
# [110]	valid_0's multi_logloss: 1.34335	valid_0's f1_score: 0.414038
# [111]	valid_0's multi_logloss: 1.34335	valid_0's f1_score: 0.413777
# [112]	valid_0's multi_logloss: 1.34332	valid_0's f1_score: 0.413895
# [113]	valid_0's multi_logloss: 1.34326	valid_0's f1_score: 0.414055
# [114]	valid_0's multi_logloss: 1.34323	valid_0's f1_score: 0.414123
# [115]	valid_0's multi_logloss: 1.3434	valid_0's f1_score: 0.414007
# [116]	valid_0's multi_logloss: 1.3433	valid_0's f1_score: 0.413863
# [117]	valid_0's multi_logloss: 1.34322	valid_0's f1_score: 0.414025
# [118]	valid_0's multi_logloss: 1.34325	valid_0's f1_score: 0.413797
# [119]	valid_0's multi_logloss: 1.34323	valid_0's f1_score: 0.414024
# [120]	valid_0's multi_logloss: 1.34326	valid_0's f1_score: 0.413757
# [121]	valid_0's multi_logloss: 1.34331	valid_0's f1_score: 0.413927
# [122]	valid_0's multi_logloss: 1.34326	valid_0's f1_score: 0.413741
# [123]	valid_0's multi_logloss: 1.34313	valid_0's f1_score: 0.413927
# [124]	valid_0's multi_logloss: 1.34315	valid_0's f1_score: 0.414042
# [125]	valid_0's multi_logloss: 1.34311	valid_0's f1_score: 0.414228
# [126]	valid_0's multi_logloss: 1.34308	valid_0's f1_score: 0.414204
# [127]	valid_0's multi_logloss: 1.34303	valid_0's f1_score: 0.414321
# [128]	valid_0's multi_logloss: 1.34299	valid_0's f1_score: 0.414466
# [129]	valid_0's multi_logloss: 1.3429	valid_0's f1_score: 0.414225
# [130]	valid_0's multi_logloss: 1.34299	valid_0's f1_score: 0.414389
# [131]	valid_0's multi_logloss: 1.34291	valid_0's f1_score: 0.414465
# [132]	valid_0's multi_logloss: 1.34299	valid_0's f1_score: 0.414324
# [133]	valid_0's multi_logloss: 1.34288	valid_0's f1_score: 0.414254
# [134]	valid_0's multi_logloss: 1.34279	valid_0's f1_score: 0.414198
# [135]	valid_0's multi_logloss: 1.34269	valid_0's f1_score: 0.414291
# [136]	valid_0's multi_logloss: 1.3427	valid_0's f1_score: 0.414394
# [137]	valid_0's multi_logloss: 1.34271	valid_0's f1_score: 0.414389
# [138]	valid_0's multi_logloss: 1.3427	valid_0's f1_score: 0.414573
# [139]	valid_0's multi_logloss: 1.3427	valid_0's f1_score: 0.414631
# [140]	valid_0's multi_logloss: 1.34283	valid_0's f1_score: 0.414471
# [141]	valid_0's multi_logloss: 1.34288	valid_0's f1_score: 0.414391
# [142]	valid_0's multi_logloss: 1.34279	valid_0's f1_score: 0.414269
# [143]	valid_0's multi_logloss: 1.34288	valid_0's f1_score: 0.41453
# [144]	valid_0's multi_logloss: 1.34279	valid_0's f1_score: 0.414404
# [145]	valid_0's multi_logloss: 1.34286	valid_0's f1_score: 0.41463
# [146]	valid_0's multi_logloss: 1.34287	valid_0's f1_score: 0.414263
# [147]	valid_0's multi_logloss: 1.34283	valid_0's f1_score: 0.414139
# [148]	valid_0's multi_logloss: 1.34285	valid_0's f1_score: 0.414358
# [149]	valid_0's multi_logloss: 1.34289	valid_0's f1_score: 0.414461
# [150]	valid_0's multi_logloss: 1.34289	valid_0's f1_score: 0.41427
# [151]	valid_0's multi_logloss: 1.34288	valid_0's f1_score: 0.414185
# [152]	valid_0's multi_logloss: 1.34284	valid_0's f1_score: 0.41426
# [153]	valid_0's multi_logloss: 1.3428	valid_0's f1_score: 0.414321
# [154]	valid_0's multi_logloss: 1.34278	valid_0's f1_score: 0.414341
# [155]	valid_0's multi_logloss: 1.34271	valid_0's f1_score: 0.414267
# [156]	valid_0's multi_logloss: 1.34281	valid_0's f1_score: 0.414142
# [157]	valid_0's multi_logloss: 1.34278	valid_0's f1_score: 0.414494
# [158]	valid_0's multi_logloss: 1.34272	valid_0's f1_score: 0.414642
# [159]	valid_0's multi_logloss: 1.3428	valid_0's f1_score: 0.414428
# [160]	valid_0's multi_logloss: 1.34276	valid_0's f1_score: 0.414515
# [161]	valid_0's multi_logloss: 1.34272	valid_0's f1_score: 0.414536
# [162]	valid_0's multi_logloss: 1.34271	valid_0's f1_score: 0.414473
# [163]	valid_0's multi_logloss: 1.34267	valid_0's f1_score: 0.41442
# [164]	valid_0's multi_logloss: 1.34266	valid_0's f1_score: 0.41446
# [165]	valid_0's multi_logloss: 1.34273	valid_0's f1_score: 0.414455
# [166]	valid_0's multi_logloss: 1.34275	valid_0's f1_score: 0.414563
# [167]	valid_0's multi_logloss: 1.34277	valid_0's f1_score: 0.414773
# [168]	valid_0's multi_logloss: 1.34275	valid_0's f1_score: 0.414739
# [169]	valid_0's multi_logloss: 1.34272	valid_0's f1_score: 0.414692
# [170]	valid_0's multi_logloss: 1.34271	valid_0's f1_score: 0.414591
# [171]	valid_0's multi_logloss: 1.34258	valid_0's f1_score: 0.414552
# [172]	valid_0's multi_logloss: 1.3426	valid_0's f1_score: 0.414494
# [173]	valid_0's multi_logloss: 1.34276	valid_0's f1_score: 0.414438
# [174]	valid_0's multi_logloss: 1.34282	valid_0's f1_score: 0.414335
# [175]	valid_0's multi_logloss: 1.34283	valid_0's f1_score: 0.414193
# [176]	valid_0's multi_logloss: 1.34281	valid_0's f1_score: 0.414276
# [177]	valid_0's multi_logloss: 1.34284	valid_0's f1_score: 0.414273
# [178]	valid_0's multi_logloss: 1.34278	valid_0's f1_score: 0.414232
# [179]	valid_0's multi_logloss: 1.34282	valid_0's f1_score: 0.41416
# [180]	valid_0's multi_logloss: 1.34277	valid_0's f1_score: 0.414239
# [181]	valid_0's multi_logloss: 1.34289	valid_0's f1_score: 0.4142
# [182]	valid_0's multi_logloss: 1.3428	valid_0's f1_score: 0.414178
# [183]	valid_0's multi_logloss: 1.34275	valid_0's f1_score: 0.414269
# [184]	valid_0's multi_logloss: 1.34286	valid_0's f1_score: 0.414362
# [185]	valid_0's multi_logloss: 1.34282	valid_0's f1_score: 0.414215
# [186]	valid_0's multi_logloss: 1.34283	valid_0's f1_score: 0.414244
# [187]	valid_0's multi_logloss: 1.3428	valid_0's f1_score: 0.41424
# [188]	valid_0's multi_logloss: 1.34294	valid_0's f1_score: 0.414243
# [189]	valid_0's multi_logloss: 1.34301	valid_0's f1_score: 0.414185
# [190]	valid_0's multi_logloss: 1.34286	valid_0's f1_score: 0.414147
# [191]	valid_0's multi_logloss: 1.34288	valid_0's f1_score: 0.414124
# [192]	valid_0's multi_logloss: 1.34292	valid_0's f1_score: 0.414059
# [193]	valid_0's multi_logloss: 1.34295	valid_0's f1_score: 0.414083
# [194]	valid_0's multi_logloss: 1.34287	valid_0's f1_score: 0.413934
# [195]	valid_0's multi_logloss: 1.34291	valid_0's f1_score: 0.413962
# [196]	valid_0's multi_logloss: 1.34295	valid_0's f1_score: 0.413866
# [197]	valid_0's multi_logloss: 1.34301	valid_0's f1_score: 0.413846
# [198]	valid_0's multi_logloss: 1.34302	valid_0's f1_score: 0.413713
# [199]	valid_0's multi_logloss: 1.34308	valid_0's f1_score: 0.413674
# [200]	valid_0's multi_logloss: 1.34313	valid_0's f1_score: 0.41383
# [201]	valid_0's multi_logloss: 1.34309	valid_0's f1_score: 0.413837
# [202]	valid_0's multi_logloss: 1.34304	valid_0's f1_score: 0.413781
# [203]	valid_0's multi_logloss: 1.34298	valid_0's f1_score: 0.41395
# [204]	valid_0's multi_logloss: 1.34307	valid_0's f1_score: 0.413742
# [205]	valid_0's multi_logloss: 1.34308	valid_0's f1_score: 0.413875
# [206]	valid_0's multi_logloss: 1.34303	valid_0's f1_score: 0.413773
# [207]	valid_0's multi_logloss: 1.34304	valid_0's f1_score: 0.413697
# [208]	valid_0's multi_logloss: 1.34311	valid_0's f1_score: 0.413772
# [209]	valid_0's multi_logloss: 1.34316	valid_0's f1_score: 0.413872
# [210]	valid_0's multi_logloss: 1.34312	valid_0's f1_score: 0.413816
# [211]	valid_0's multi_logloss: 1.34319	valid_0's f1_score: 0.413896
# [212]	valid_0's multi_logloss: 1.34314	valid_0's f1_score: 0.413684
# [213]	valid_0's multi_logloss: 1.34313	valid_0's f1_score: 0.413682
# [214]	valid_0's multi_logloss: 1.34318	valid_0's f1_score: 0.413804
# [215]	valid_0's multi_logloss: 1.34315	valid_0's f1_score: 0.413879
# [216]	valid_0's multi_logloss: 1.34316	valid_0's f1_score: 0.413862
# [217]	valid_0's multi_logloss: 1.34318	valid_0's f1_score: 0.413852
# [218]	valid_0's multi_logloss: 1.34317	valid_0's f1_score: 0.413782
# [219]	valid_0's multi_logloss: 1.34319	valid_0's f1_score: 0.413857
# [220]	valid_0's multi_logloss: 1.3432	valid_0's f1_score: 0.413875
# [221]	valid_0's multi_logloss: 1.34324	valid_0's f1_score: 0.413863
# [222]	valid_0's multi_logloss: 1.34327	valid_0's f1_score: 0.413847
# [223]	valid_0's multi_logloss: 1.34331	valid_0's f1_score: 0.413717
# [224]	valid_0's multi_logloss: 1.34331	valid_0's f1_score: 0.413737
# [225]	valid_0's multi_logloss: 1.34335	valid_0's f1_score: 0.41373
# [226]	valid_0's multi_logloss: 1.34335	valid_0's f1_score: 0.413776
# [227]	valid_0's multi_logloss: 1.34333	valid_0's f1_score: 0.413787
# [228]	valid_0's multi_logloss: 1.34334	valid_0's f1_score: 0.413726
# [229]	valid_0's multi_logloss: 1.34337	valid_0's f1_score: 0.413874
# [230]	valid_0's multi_logloss: 1.34338	valid_0's f1_score: 0.413937
# [231]	valid_0's multi_logloss: 1.3434	valid_0's f1_score: 0.413901
# [232]	valid_0's multi_logloss: 1.34342	valid_0's f1_score: 0.41388
# [233]	valid_0's multi_logloss: 1.34346	valid_0's f1_score: 0.413891
# [234]	valid_0's multi_logloss: 1.34346	valid_0's f1_score: 0.413795
# [235]	valid_0's multi_logloss: 1.34348	valid_0's f1_score: 0.413675
# [236]	valid_0's multi_logloss: 1.34347	valid_0's f1_score: 0.413634
# [237]	valid_0's multi_logloss: 1.34345	valid_0's f1_score: 0.413628
# [238]	valid_0's multi_logloss: 1.3434	valid_0's f1_score: 0.413637
# [239]	valid_0's multi_logloss: 1.34339	valid_0's f1_score: 0.413645
# [240]	valid_0's multi_logloss: 1.34338	valid_0's f1_score: 0.413592
# [241]	valid_0's multi_logloss: 1.34345	valid_0's f1_score: 0.413697
# [242]	valid_0's multi_logloss: 1.34351	valid_0's f1_score: 0.413557
# [243]	valid_0's multi_logloss: 1.34341	valid_0's f1_score: 0.413715
# [244]	valid_0's multi_logloss: 1.3434	valid_0's f1_score: 0.413734
# [245]	valid_0's multi_logloss: 1.34339	valid_0's f1_score: 0.413853
# [246]	valid_0's multi_logloss: 1.34338	valid_0's f1_score: 0.413812
# [247]	valid_0's multi_logloss: 1.34337	valid_0's f1_score: 0.413794
# [248]	valid_0's multi_logloss: 1.34337	valid_0's f1_score: 0.413761
# [249]	valid_0's multi_logloss: 1.34337	valid_0's f1_score: 0.413822
# [250]	valid_0's multi_logloss: 1.34379	valid_0's f1_score: 0.413769
# Did not meet early stopping. Best iteration is:
# [171]	valid_0's multi_logloss: 1.34258	valid_0's f1_score: 0.414552
# 0.41455239272512046
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	valid_0's multi_logloss: 1.76355	valid_0's f1_score: 0.0900657
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 1.67955	valid_0's f1_score: 0.192013
# [3]	valid_0's multi_logloss: 1.619	valid_0's f1_score: 0.280974
# [4]	valid_0's multi_logloss: 1.57243	valid_0's f1_score: 0.326533
# [5]	valid_0's multi_logloss: 1.53654	valid_0's f1_score: 0.35009
# [6]	valid_0's multi_logloss: 1.50701	valid_0's f1_score: 0.363155
# [7]	valid_0's multi_logloss: 1.48308	valid_0's f1_score: 0.372222
# [8]	valid_0's multi_logloss: 1.46365	valid_0's f1_score: 0.379848
# [9]	valid_0's multi_logloss: 1.44739	valid_0's f1_score: 0.384477
# [10]	valid_0's multi_logloss: 1.43419	valid_0's f1_score: 0.388037
# [11]	valid_0's multi_logloss: 1.42334	valid_0's f1_score: 0.391125
# [12]	valid_0's multi_logloss: 1.41383	valid_0's f1_score: 0.393219
# [13]	valid_0's multi_logloss: 1.40635	valid_0's f1_score: 0.395177
# [14]	valid_0's multi_logloss: 1.3996	valid_0's f1_score: 0.397153
# [15]	valid_0's multi_logloss: 1.39346	valid_0's f1_score: 0.398712
# [16]	valid_0's multi_logloss: 1.38841	valid_0's f1_score: 0.400571
# [17]	valid_0's multi_logloss: 1.38394	valid_0's f1_score: 0.401487
# [18]	valid_0's multi_logloss: 1.38007	valid_0's f1_score: 0.403173
# [19]	valid_0's multi_logloss: 1.3773	valid_0's f1_score: 0.404175
# [20]	valid_0's multi_logloss: 1.37463	valid_0's f1_score: 0.404691
# [21]	valid_0's multi_logloss: 1.37285	valid_0's f1_score: 0.405564
# [22]	valid_0's multi_logloss: 1.37057	valid_0's f1_score: 0.405808
# [23]	valid_0's multi_logloss: 1.36924	valid_0's f1_score: 0.406876
# [24]	valid_0's multi_logloss: 1.36725	valid_0's f1_score: 0.406954
# [25]	valid_0's multi_logloss: 1.36602	valid_0's f1_score: 0.407889
# [26]	valid_0's multi_logloss: 1.36453	valid_0's f1_score: 0.407753
# [27]	valid_0's multi_logloss: 1.36328	valid_0's f1_score: 0.407806
# [28]	valid_0's multi_logloss: 1.36205	valid_0's f1_score: 0.408263
# [29]	valid_0's multi_logloss: 1.36096	valid_0's f1_score: 0.408386
# [30]	valid_0's multi_logloss: 1.36017	valid_0's f1_score: 0.408976
# [31]	valid_0's multi_logloss: 1.35914	valid_0's f1_score: 0.409184
# [32]	valid_0's multi_logloss: 1.35846	valid_0's f1_score: 0.408846
# [33]	valid_0's multi_logloss: 1.35773	valid_0's f1_score: 0.409099
# [34]	valid_0's multi_logloss: 1.35729	valid_0's f1_score: 0.408897
# [35]	valid_0's multi_logloss: 1.35634	valid_0's f1_score: 0.409522
# [36]	valid_0's multi_logloss: 1.35624	valid_0's f1_score: 0.409683
# [37]	valid_0's multi_logloss: 1.35595	valid_0's f1_score: 0.409664
# [38]	valid_0's multi_logloss: 1.3554	valid_0's f1_score: 0.409747
# [39]	valid_0's multi_logloss: 1.35505	valid_0's f1_score: 0.410129
# [40]	valid_0's multi_logloss: 1.35599	valid_0's f1_score: 0.410161
# [41]	valid_0's multi_logloss: 1.3556	valid_0's f1_score: 0.410187
# [42]	valid_0's multi_logloss: 1.35516	valid_0's f1_score: 0.410229
# [43]	valid_0's multi_logloss: 1.35503	valid_0's f1_score: 0.410408
# [44]	valid_0's multi_logloss: 1.35456	valid_0's f1_score: 0.410698
# [45]	valid_0's multi_logloss: 1.3545	valid_0's f1_score: 0.411015
# [46]	valid_0's multi_logloss: 1.3542	valid_0's f1_score: 0.411333
# [47]	valid_0's multi_logloss: 1.35405	valid_0's f1_score: 0.41111
# [48]	valid_0's multi_logloss: 1.35373	valid_0's f1_score: 0.411423
# [49]	valid_0's multi_logloss: 1.3534	valid_0's f1_score: 0.411458
# [50]	valid_0's multi_logloss: 1.35336	valid_0's f1_score: 0.411349
# [51]	valid_0's multi_logloss: 1.35302	valid_0's f1_score: 0.411458
# [52]	valid_0's multi_logloss: 1.35286	valid_0's f1_score: 0.411031
# [53]	valid_0's multi_logloss: 1.3526	valid_0's f1_score: 0.411162
# [54]	valid_0's multi_logloss: 1.35258	valid_0's f1_score: 0.411464
# [55]	valid_0's multi_logloss: 1.35242	valid_0's f1_score: 0.411701
# [56]	valid_0's multi_logloss: 1.35233	valid_0's f1_score: 0.41156
# [57]	valid_0's multi_logloss: 1.35241	valid_0's f1_score: 0.411767
# [58]	valid_0's multi_logloss: 1.35234	valid_0's f1_score: 0.411748
# [59]	valid_0's multi_logloss: 1.35219	valid_0's f1_score: 0.412112
# [60]	valid_0's multi_logloss: 1.35183	valid_0's f1_score: 0.411884
# [61]	valid_0's multi_logloss: 1.35155	valid_0's f1_score: 0.411906
# [62]	valid_0's multi_logloss: 1.3514	valid_0's f1_score: 0.411949
# [63]	valid_0's multi_logloss: 1.35145	valid_0's f1_score: 0.411392
# [64]	valid_0's multi_logloss: 1.35137	valid_0's f1_score: 0.412183
# [65]	valid_0's multi_logloss: 1.35114	valid_0's f1_score: 0.41211
# [66]	valid_0's multi_logloss: 1.35101	valid_0's f1_score: 0.41221
# [67]	valid_0's multi_logloss: 1.35073	valid_0's f1_score: 0.412286
# [68]	valid_0's multi_logloss: 1.35045	valid_0's f1_score: 0.412625
# [69]	valid_0's multi_logloss: 1.35025	valid_0's f1_score: 0.412804
# [70]	valid_0's multi_logloss: 1.35023	valid_0's f1_score: 0.412973
# [71]	valid_0's multi_logloss: 1.35015	valid_0's f1_score: 0.413121
# [72]	valid_0's multi_logloss: 1.35011	valid_0's f1_score: 0.412953
# [73]	valid_0's multi_logloss: 1.34994	valid_0's f1_score: 0.412941
# [74]	valid_0's multi_logloss: 1.34964	valid_0's f1_score: 0.412672
# [75]	valid_0's multi_logloss: 1.34962	valid_0's f1_score: 0.412748
# [76]	valid_0's multi_logloss: 1.34949	valid_0's f1_score: 0.413155
# [77]	valid_0's multi_logloss: 1.34929	valid_0's f1_score: 0.412746
# [78]	valid_0's multi_logloss: 1.34919	valid_0's f1_score: 0.413009
# [79]	valid_0's multi_logloss: 1.34918	valid_0's f1_score: 0.412934
# [80]	valid_0's multi_logloss: 1.34894	valid_0's f1_score: 0.412902
# [81]	valid_0's multi_logloss: 1.34868	valid_0's f1_score: 0.413245
# [82]	valid_0's multi_logloss: 1.34831	valid_0's f1_score: 0.413034
# [83]	valid_0's multi_logloss: 1.34829	valid_0's f1_score: 0.412717
# [84]	valid_0's multi_logloss: 1.34836	valid_0's f1_score: 0.413061
# [85]	valid_0's multi_logloss: 1.34823	valid_0's f1_score: 0.413114
# [86]	valid_0's multi_logloss: 1.3484	valid_0's f1_score: 0.413086
# [87]	valid_0's multi_logloss: 1.34829	valid_0's f1_score: 0.412695
# [88]	valid_0's multi_logloss: 1.34839	valid_0's f1_score: 0.412878
# [89]	valid_0's multi_logloss: 1.3483	valid_0's f1_score: 0.413253
# [90]	valid_0's multi_logloss: 1.34822	valid_0's f1_score: 0.413167
# [91]	valid_0's multi_logloss: 1.34792	valid_0's f1_score: 0.412923
# [92]	valid_0's multi_logloss: 1.34767	valid_0's f1_score: 0.413158
# [93]	valid_0's multi_logloss: 1.34761	valid_0's f1_score: 0.413264
# [94]	valid_0's multi_logloss: 1.34752	valid_0's f1_score: 0.413193
# [95]	valid_0's multi_logloss: 1.34749	valid_0's f1_score: 0.41347
# [96]	valid_0's multi_logloss: 1.34734	valid_0's f1_score: 0.413429
# [97]	valid_0's multi_logloss: 1.34743	valid_0's f1_score: 0.413416
# [98]	valid_0's multi_logloss: 1.34784	valid_0's f1_score: 0.413121
# [99]	valid_0's multi_logloss: 1.34776	valid_0's f1_score: 0.413174
# [100]	valid_0's multi_logloss: 1.34768	valid_0's f1_score: 0.413491
# [101]	valid_0's multi_logloss: 1.3478	valid_0's f1_score: 0.413265
# [102]	valid_0's multi_logloss: 1.34789	valid_0's f1_score: 0.413352
# [103]	valid_0's multi_logloss: 1.34796	valid_0's f1_score: 0.413204
# [104]	valid_0's multi_logloss: 1.34787	valid_0's f1_score: 0.413238
# [105]	valid_0's multi_logloss: 1.34764	valid_0's f1_score: 0.413472
# [106]	valid_0's multi_logloss: 1.34765	valid_0's f1_score: 0.41334
# [107]	valid_0's multi_logloss: 1.34777	valid_0's f1_score: 0.413294
# [108]	valid_0's multi_logloss: 1.34771	valid_0's f1_score: 0.412866
# [109]	valid_0's multi_logloss: 1.34767	valid_0's f1_score: 0.413173
# [110]	valid_0's multi_logloss: 1.34787	valid_0's f1_score: 0.413284
# [111]	valid_0's multi_logloss: 1.34776	valid_0's f1_score: 0.41321
# [112]	valid_0's multi_logloss: 1.34767	valid_0's f1_score: 0.413235
# [113]	valid_0's multi_logloss: 1.34756	valid_0's f1_score: 0.412838
# [114]	valid_0's multi_logloss: 1.34758	valid_0's f1_score: 0.413002
# [115]	valid_0's multi_logloss: 1.34753	valid_0's f1_score: 0.413277
# [116]	valid_0's multi_logloss: 1.34742	valid_0's f1_score: 0.413301
# [117]	valid_0's multi_logloss: 1.34755	valid_0's f1_score: 0.41318
# [118]	valid_0's multi_logloss: 1.34749	valid_0's f1_score: 0.413223
# [119]	valid_0's multi_logloss: 1.34743	valid_0's f1_score: 0.413418
# [120]	valid_0's multi_logloss: 1.34737	valid_0's f1_score: 0.413189
# [121]	valid_0's multi_logloss: 1.34732	valid_0's f1_score: 0.413167
# [122]	valid_0's multi_logloss: 1.34724	valid_0's f1_score: 0.413528
# [123]	valid_0's multi_logloss: 1.34715	valid_0's f1_score: 0.413718
# [124]	valid_0's multi_logloss: 1.34718	valid_0's f1_score: 0.413663
# [125]	valid_0's multi_logloss: 1.34721	valid_0's f1_score: 0.413359
# [126]	valid_0's multi_logloss: 1.34735	valid_0's f1_score: 0.413637
# [127]	valid_0's multi_logloss: 1.34734	valid_0's f1_score: 0.41376
# [128]	valid_0's multi_logloss: 1.34728	valid_0's f1_score: 0.413866
# [129]	valid_0's multi_logloss: 1.34719	valid_0's f1_score: 0.413948
# [130]	valid_0's multi_logloss: 1.34726	valid_0's f1_score: 0.413815
# [131]	valid_0's multi_logloss: 1.34735	valid_0's f1_score: 0.41363
# [132]	valid_0's multi_logloss: 1.34728	valid_0's f1_score: 0.413615
# [133]	valid_0's multi_logloss: 1.34733	valid_0's f1_score: 0.41343
# [134]	valid_0's multi_logloss: 1.34736	valid_0's f1_score: 0.413345
# [135]	valid_0's multi_logloss: 1.34739	valid_0's f1_score: 0.413264
# [136]	valid_0's multi_logloss: 1.34728	valid_0's f1_score: 0.413307
# [137]	valid_0's multi_logloss: 1.34699	valid_0's f1_score: 0.413415
# [138]	valid_0's multi_logloss: 1.34698	valid_0's f1_score: 0.413315
# [139]	valid_0's multi_logloss: 1.34702	valid_0's f1_score: 0.413508
# [140]	valid_0's multi_logloss: 1.34703	valid_0's f1_score: 0.413156
# [141]	valid_0's multi_logloss: 1.34706	valid_0's f1_score: 0.413302
# [142]	valid_0's multi_logloss: 1.34698	valid_0's f1_score: 0.413122
# [143]	valid_0's multi_logloss: 1.34697	valid_0's f1_score: 0.413041
# [144]	valid_0's multi_logloss: 1.34688	valid_0's f1_score: 0.413089
# [145]	valid_0's multi_logloss: 1.34687	valid_0's f1_score: 0.413109
# [146]	valid_0's multi_logloss: 1.3469	valid_0's f1_score: 0.412863
# [147]	valid_0's multi_logloss: 1.34693	valid_0's f1_score: 0.41306
# [148]	valid_0's multi_logloss: 1.34687	valid_0's f1_score: 0.413588
# [149]	valid_0's multi_logloss: 1.34686	valid_0's f1_score: 0.413576
# [150]	valid_0's multi_logloss: 1.34678	valid_0's f1_score: 0.413406
# [151]	valid_0's multi_logloss: 1.34676	valid_0's f1_score: 0.413383
# [152]	valid_0's multi_logloss: 1.34674	valid_0's f1_score: 0.41336
# [153]	valid_0's multi_logloss: 1.34674	valid_0's f1_score: 0.413416
# [154]	valid_0's multi_logloss: 1.34676	valid_0's f1_score: 0.413202
# [155]	valid_0's multi_logloss: 1.34677	valid_0's f1_score: 0.413155
# [156]	valid_0's multi_logloss: 1.34675	valid_0's f1_score: 0.413231
# [157]	valid_0's multi_logloss: 1.3468	valid_0's f1_score: 0.413065
# [158]	valid_0's multi_logloss: 1.34671	valid_0's f1_score: 0.413209
# [159]	valid_0's multi_logloss: 1.34681	valid_0's f1_score: 0.413362
# [160]	valid_0's multi_logloss: 1.34673	valid_0's f1_score: 0.413419
# [161]	valid_0's multi_logloss: 1.34661	valid_0's f1_score: 0.41351
# [162]	valid_0's multi_logloss: 1.34663	valid_0's f1_score: 0.41336
# [163]	valid_0's multi_logloss: 1.34661	valid_0's f1_score: 0.413201
# [164]	valid_0's multi_logloss: 1.34654	valid_0's f1_score: 0.413351
# [165]	valid_0's multi_logloss: 1.34652	valid_0's f1_score: 0.413388
# [166]	valid_0's multi_logloss: 1.34648	valid_0's f1_score: 0.413486
# [167]	valid_0's multi_logloss: 1.34656	valid_0's f1_score: 0.413759
# [168]	valid_0's multi_logloss: 1.34664	valid_0's f1_score: 0.413708
# [169]	valid_0's multi_logloss: 1.34667	valid_0's f1_score: 0.41344
# [170]	valid_0's multi_logloss: 1.3467	valid_0's f1_score: 0.413538
# [171]	valid_0's multi_logloss: 1.34673	valid_0's f1_score: 0.413521
# [172]	valid_0's multi_logloss: 1.34669	valid_0's f1_score: 0.413567
# [173]	valid_0's multi_logloss: 1.34671	valid_0's f1_score: 0.413401
# [174]	valid_0's multi_logloss: 1.34667	valid_0's f1_score: 0.413516
# [175]	valid_0's multi_logloss: 1.34671	valid_0's f1_score: 0.413613
# [176]	valid_0's multi_logloss: 1.34669	valid_0's f1_score: 0.413589
# [177]	valid_0's multi_logloss: 1.34673	valid_0's f1_score: 0.41359
# [178]	valid_0's multi_logloss: 1.34675	valid_0's f1_score: 0.413665
# [179]	valid_0's multi_logloss: 1.34674	valid_0's f1_score: 0.413559
# [180]	valid_0's multi_logloss: 1.34681	valid_0's f1_score: 0.413227
# [181]	valid_0's multi_logloss: 1.34703	valid_0's f1_score: 0.413162
# [182]	valid_0's multi_logloss: 1.34701	valid_0's f1_score: 0.413281
# [183]	valid_0's multi_logloss: 1.34705	valid_0's f1_score: 0.413261
# [184]	valid_0's multi_logloss: 1.34709	valid_0's f1_score: 0.413396
# [185]	valid_0's multi_logloss: 1.34713	valid_0's f1_score: 0.413352
# [186]	valid_0's multi_logloss: 1.34711	valid_0's f1_score: 0.413362
# [187]	valid_0's multi_logloss: 1.3471	valid_0's f1_score: 0.413388
# [188]	valid_0's multi_logloss: 1.34716	valid_0's f1_score: 0.413541
# [189]	valid_0's multi_logloss: 1.34707	valid_0's f1_score: 0.413307
# [190]	valid_0's multi_logloss: 1.3471	valid_0's f1_score: 0.41351
# [191]	valid_0's multi_logloss: 1.34712	valid_0's f1_score: 0.413575
# [192]	valid_0's multi_logloss: 1.34713	valid_0's f1_score: 0.413747
# [193]	valid_0's multi_logloss: 1.34716	valid_0's f1_score: 0.413626
# [194]	valid_0's multi_logloss: 1.34716	valid_0's f1_score: 0.41386
# [195]	valid_0's multi_logloss: 1.34719	valid_0's f1_score: 0.413859
# [196]	valid_0's multi_logloss: 1.34727	valid_0's f1_score: 0.413715
# [197]	valid_0's multi_logloss: 1.34729	valid_0's f1_score: 0.413863
# [198]	valid_0's multi_logloss: 1.34733	valid_0's f1_score: 0.413862
# [199]	valid_0's multi_logloss: 1.34729	valid_0's f1_score: 0.413848
# [200]	valid_0's multi_logloss: 1.34732	valid_0's f1_score: 0.41377
# [201]	valid_0's multi_logloss: 1.34724	valid_0's f1_score: 0.413683
# [202]	valid_0's multi_logloss: 1.34725	valid_0's f1_score: 0.413633
# [203]	valid_0's multi_logloss: 1.34724	valid_0's f1_score: 0.413642
# [204]	valid_0's multi_logloss: 1.34718	valid_0's f1_score: 0.413644
# [205]	valid_0's multi_logloss: 1.3471	valid_0's f1_score: 0.413598
# [206]	valid_0's multi_logloss: 1.34714	valid_0's f1_score: 0.413509
# [207]	valid_0's multi_logloss: 1.34711	valid_0's f1_score: 0.413518
# [208]	valid_0's multi_logloss: 1.34718	valid_0's f1_score: 0.413573
# [209]	valid_0's multi_logloss: 1.34712	valid_0's f1_score: 0.413575
# [210]	valid_0's multi_logloss: 1.34713	valid_0's f1_score: 0.413525
# [211]	valid_0's multi_logloss: 1.34708	valid_0's f1_score: 0.413605
# [212]	valid_0's multi_logloss: 1.34709	valid_0's f1_score: 0.413655
# [213]	valid_0's multi_logloss: 1.34707	valid_0's f1_score: 0.413499
# [214]	valid_0's multi_logloss: 1.34713	valid_0's f1_score: 0.413457
# [215]	valid_0's multi_logloss: 1.34712	valid_0's f1_score: 0.413417
# [216]	valid_0's multi_logloss: 1.34711	valid_0's f1_score: 0.413411
# [217]	valid_0's multi_logloss: 1.34774	valid_0's f1_score: 0.413899
# [218]	valid_0's multi_logloss: 1.34775	valid_0's f1_score: 0.413849
# [219]	valid_0's multi_logloss: 1.34776	valid_0's f1_score: 0.413615
# [220]	valid_0's multi_logloss: 1.34778	valid_0's f1_score: 0.413581
# [221]	valid_0's multi_logloss: 1.34779	valid_0's f1_score: 0.413646
# [222]	valid_0's multi_logloss: 1.34778	valid_0's f1_score: 0.413492
# [223]	valid_0's multi_logloss: 1.34795	valid_0's f1_score: 0.413401
# [224]	valid_0's multi_logloss: 1.34795	valid_0's f1_score: 0.413456
# [225]	valid_0's multi_logloss: 1.34787	valid_0's f1_score: 0.413293
# [226]	valid_0's multi_logloss: 1.34789	valid_0's f1_score: 0.413236
# [227]	valid_0's multi_logloss: 1.34789	valid_0's f1_score: 0.413142
# [228]	valid_0's multi_logloss: 1.34787	valid_0's f1_score: 0.413134
# [229]	valid_0's multi_logloss: 1.34802	valid_0's f1_score: 0.413256
# Early stopping, best iteration is:
# [129]	valid_0's multi_logloss: 1.34719	valid_0's f1_score: 0.413948
# 0.41394759626853334
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	valid_0's multi_logloss: 1.76277	valid_0's f1_score: 0.0874505
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 1.67912	valid_0's f1_score: 0.18973
# [3]	valid_0's multi_logloss: 1.61887	valid_0's f1_score: 0.280157
# [4]	valid_0's multi_logloss: 1.57218	valid_0's f1_score: 0.331759
# [5]	valid_0's multi_logloss: 1.53559	valid_0's f1_score: 0.353088
# [6]	valid_0's multi_logloss: 1.50623	valid_0's f1_score: 0.366091
# [7]	valid_0's multi_logloss: 1.48268	valid_0's f1_score: 0.374471
# [8]	valid_0's multi_logloss: 1.46306	valid_0's f1_score: 0.380396
# [9]	valid_0's multi_logloss: 1.44716	valid_0's f1_score: 0.386062
# [10]	valid_0's multi_logloss: 1.43415	valid_0's f1_score: 0.389791
# [11]	valid_0's multi_logloss: 1.42294	valid_0's f1_score: 0.392199
# [12]	valid_0's multi_logloss: 1.41353	valid_0's f1_score: 0.394285
# [13]	valid_0's multi_logloss: 1.40561	valid_0's f1_score: 0.395609
# [14]	valid_0's multi_logloss: 1.39916	valid_0's f1_score: 0.397458
# [15]	valid_0's multi_logloss: 1.39371	valid_0's f1_score: 0.39986
# [16]	valid_0's multi_logloss: 1.38888	valid_0's f1_score: 0.400776
# [17]	valid_0's multi_logloss: 1.38462	valid_0's f1_score: 0.401899
# [18]	valid_0's multi_logloss: 1.3805	valid_0's f1_score: 0.402849
# [19]	valid_0's multi_logloss: 1.37755	valid_0's f1_score: 0.404182
# [20]	valid_0's multi_logloss: 1.37517	valid_0's f1_score: 0.404747
# [21]	valid_0's multi_logloss: 1.37274	valid_0's f1_score: 0.405961
# [22]	valid_0's multi_logloss: 1.37058	valid_0's f1_score: 0.406308
# [23]	valid_0's multi_logloss: 1.36849	valid_0's f1_score: 0.407098
# [24]	valid_0's multi_logloss: 1.3668	valid_0's f1_score: 0.407319
# [25]	valid_0's multi_logloss: 1.36498	valid_0's f1_score: 0.408059
# [26]	valid_0's multi_logloss: 1.36372	valid_0's f1_score: 0.408281
# [27]	valid_0's multi_logloss: 1.36355	valid_0's f1_score: 0.408048
# [28]	valid_0's multi_logloss: 1.36245	valid_0's f1_score: 0.408696
# ...
# [197]	valid_0's multi_logloss: 1.34732	valid_0's f1_score: 0.412084
# [198]	valid_0's multi_logloss: 1.34734	valid_0's f1_score: 0.412013
# [199]	valid_0's multi_logloss: 1.34729	valid_0's f1_score: 0.412126
# [200]	valid_0's multi_logloss: 1.3474	valid_0's f1_score: 0.412215
# [201]	valid_0's multi_logloss: 1.34729	valid_0's f1_score: 0.412268
# [202]	valid_0's multi_logloss: 1.34727	valid_0's f1_score: 0.412197
# [203]	valid_0's multi_logloss: 1.34725	valid_0's f1_score: 0.412178
# [204]	valid_0's multi_logloss: 1.34724	valid_0's f1_score: 0.412054
# [205]	valid_0's multi_logloss: 1.34727	valid_0's f1_score: 0.411901
# [206]	valid_0's multi_logloss: 1.34731	valid_0's f1_score: 0.411938
# [207]	valid_0's multi_logloss: 1.34734	valid_0's f1_score: 0.411889
# [208]	valid_0's multi_logloss: 1.34733	valid_0's f1_score: 0.41201
# [209]	valid_0's multi_logloss: 1.34735	valid_0's f1_score: 0.412205
# [210]	valid_0's multi_logloss: 1.34734	valid_0's f1_score: 0.412063
# [211]	valid_0's multi_logloss: 1.34735	valid_0's f1_score: 0.412141
# [212]	valid_0's multi_logloss: 1.34748	valid_0's f1_score: 0.412001
# [213]	valid_0's multi_logloss: 1.34747	valid_0's f1_score: 0.411984
# [214]	valid_0's multi_logloss: 1.34745	valid_0's f1_score: 0.411994
# [215]	valid_0's multi_logloss: 1.34746	valid_0's f1_score: 0.411907
# [216]	valid_0's multi_logloss: 1.34748	valid_0's f1_score: 0.411873
# [217]	valid_0's multi_logloss: 1.34749	valid_0's f1_score: 0.411773
# [218]	valid_0's multi_logloss: 1.3476	valid_0's f1_score: 0.411836
# [219]	valid_0's multi_logloss: 1.34759	valid_0's f1_score: 0.411843
# [220]	valid_0's multi_logloss: 1.34738	valid_0's f1_score: 0.411751
# Early stopping, best iteration is:
# [120]	valid_0's multi_logloss: 1.34752	valid_0's f1_score: 0.41347
# 0.4134700118251378
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [1]	valid_0's multi_logloss: 1.76288	valid_0's f1_score: 0.0877556
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 1.6792	valid_0's f1_score: 0.191205
# [3]	valid_0's multi_logloss: 1.61806	valid_0's f1_score: 0.284716
# [4]	valid_0's multi_logloss: 1.57145	valid_0's f1_score: 0.328298
# [5]	valid_0's multi_logloss: 1.5351	valid_0's f1_score: 0.349067
# [6]	valid_0's multi_logloss: 1.50556	valid_0's f1_score: 0.36334
# [7]	valid_0's multi_logloss: 1.48141	valid_0's f1_score: 0.373411
# [8]	valid_0's multi_logloss: 1.46208	valid_0's f1_score: 0.380298
# [9]	valid_0's multi_logloss: 1.44628	valid_0's f1_score: 0.386026
# [10]	valid_0's multi_logloss: 1.43318	valid_0's f1_score: 0.389541
# [11]	valid_0's multi_logloss: 1.4221	valid_0's f1_score: 0.392379
# [12]	valid_0's multi_logloss: 1.41272	valid_0's f1_score: 0.394382
# [13]	valid_0's multi_logloss: 1.40472	valid_0's f1_score: 0.396107
# [14]	valid_0's multi_logloss: 1.39815	valid_0's f1_score: 0.398146
# [15]	valid_0's multi_logloss: 1.39266	valid_0's f1_score: 0.399576
# [16]	valid_0's multi_logloss: 1.38765	valid_0's f1_score: 0.401043
# [17]	valid_0's multi_logloss: 1.38343	valid_0's f1_score: 0.401608
# [18]	valid_0's multi_logloss: 1.37974	valid_0's f1_score: 0.402799
# [19]	valid_0's multi_logloss: 1.37658	valid_0's f1_score: 0.403313
# [20]	valid_0's multi_logloss: 1.37352	valid_0's f1_score: 0.403856
# [21]	valid_0's multi_logloss: 1.37099	valid_0's f1_score: 0.404012
# [22]	valid_0's multi_logloss: 1.36896	valid_0's f1_score: 0.405204
# [23]	valid_0's multi_logloss: 1.36691	valid_0's f1_score: 0.405896
# [24]	valid_0's multi_logloss: 1.36557	valid_0's f1_score: 0.406127
# [25]	valid_0's multi_logloss: 1.36376	valid_0's f1_score: 0.40626
# [26]	valid_0's multi_logloss: 1.36217	valid_0's f1_score: 0.406877
# [27]	valid_0's multi_logloss: 1.3616	valid_0's f1_score: 0.407404
# [28]	valid_0's multi_logloss: 1.36063	valid_0's f1_score: 0.407918
# [29]	valid_0's multi_logloss: 1.36037	valid_0's f1_score: 0.408124
# [30]	valid_0's multi_logloss: 1.35945	valid_0's f1_score: 0.408414
# [31]	valid_0's multi_logloss: 1.35843	valid_0's f1_score: 0.408377
# [32]	valid_0's multi_logloss: 1.3576	valid_0's f1_score: 0.408338
# [33]	valid_0's multi_logloss: 1.35657	valid_0's f1_score: 0.40924
# [34]	valid_0's multi_logloss: 1.35584	valid_0's f1_score: 0.409093
# [35]	valid_0's multi_logloss: 1.35533	valid_0's f1_score: 0.409539
# [36]	valid_0's multi_logloss: 1.35519	valid_0's f1_score: 0.409352
# [37]	valid_0's multi_logloss: 1.35469	valid_0's f1_score: 0.409765
# [38]	valid_0's multi_logloss: 1.35434	valid_0's f1_score: 0.410173
# [39]	valid_0's multi_logloss: 1.35374	valid_0's f1_score: 0.41006
# [40]	valid_0's multi_logloss: 1.35317	valid_0's f1_score: 0.410246
# [41]	valid_0's multi_logloss: 1.3526	valid_0's f1_score: 0.410171
# [42]	valid_0's multi_logloss: 1.35212	valid_0's f1_score: 0.410551
# [43]	valid_0's multi_logloss: 1.35216	valid_0's f1_score: 0.410633
# [44]	valid_0's multi_logloss: 1.35173	valid_0's f1_score: 0.410808
# [45]	valid_0's multi_logloss: 1.35142	valid_0's f1_score: 0.410716
# [46]	valid_0's multi_logloss: 1.3511	valid_0's f1_score: 0.410709
# [47]	valid_0's multi_logloss: 1.35054	valid_0's f1_score: 0.41081
# [48]	valid_0's multi_logloss: 1.35022	valid_0's f1_score: 0.41066
# [49]	valid_0's multi_logloss: 1.35001	valid_0's f1_score: 0.41075
# [50]	valid_0's multi_logloss: 1.34983	valid_0's f1_score: 0.410813
# [51]	valid_0's multi_logloss: 1.34962	valid_0's f1_score: 0.411056
# [52]	valid_0's multi_logloss: 1.34938	valid_0's f1_score: 0.4111
# [53]	valid_0's multi_logloss: 1.34907	valid_0's f1_score: 0.411509
# [54]	valid_0's multi_logloss: 1.34904	valid_0's f1_score: 0.411425
# [55]	valid_0's multi_logloss: 1.3488	valid_0's f1_score: 0.411092
# [56]	valid_0's multi_logloss: 1.34852	valid_0's f1_score: 0.41106
# [57]	valid_0's multi_logloss: 1.34856	valid_0's f1_score: 0.411525
# [58]	valid_0's multi_logloss: 1.34806	valid_0's f1_score: 0.41119
# [59]	valid_0's multi_logloss: 1.34785	valid_0's f1_score: 0.411266
# [60]	valid_0's multi_logloss: 1.34779	valid_0's f1_score: 0.411557
# [61]	valid_0's multi_logloss: 1.34745	valid_0's f1_score: 0.41154
# [62]	valid_0's multi_logloss: 1.34715	valid_0's f1_score: 0.411512
# [63]	valid_0's multi_logloss: 1.34687	valid_0's f1_score: 0.411562
# [64]	valid_0's multi_logloss: 1.34686	valid_0's f1_score: 0.411795
# [65]	valid_0's multi_logloss: 1.34667	valid_0's f1_score: 0.412098
# [66]	valid_0's multi_logloss: 1.34647	valid_0's f1_score: 0.412218
# [67]	valid_0's multi_logloss: 1.34628	valid_0's f1_score: 0.412252
# [68]	valid_0's multi_logloss: 1.34618	valid_0's f1_score: 0.412132
# [69]	valid_0's multi_logloss: 1.34617	valid_0's f1_score: 0.412539
# [70]	valid_0's multi_logloss: 1.34607	valid_0's f1_score: 0.4127
# [71]	valid_0's multi_logloss: 1.34576	valid_0's f1_score: 0.412859
# [72]	valid_0's multi_logloss: 1.34556	valid_0's f1_score: 0.412568
# [73]	valid_0's multi_logloss: 1.34549	valid_0's f1_score: 0.412511
# [74]	valid_0's multi_logloss: 1.34529	valid_0's f1_score: 0.412682
# [75]	valid_0's multi_logloss: 1.34495	valid_0's f1_score: 0.412847
# [76]	valid_0's multi_logloss: 1.34474	valid_0's f1_score: 0.41292
# [77]	valid_0's multi_logloss: 1.34453	valid_0's f1_score: 0.412953
# [78]	valid_0's multi_logloss: 1.34441	valid_0's f1_score: 0.412995
# [79]	valid_0's multi_logloss: 1.34414	valid_0's f1_score: 0.413348
# [80]	valid_0's multi_logloss: 1.34398	valid_0's f1_score: 0.413644
# [81]	valid_0's multi_logloss: 1.3438	valid_0's f1_score: 0.413642
# [82]	valid_0's multi_logloss: 1.34357	valid_0's f1_score: 0.413863
# [83]	valid_0's multi_logloss: 1.34347	valid_0's f1_score: 0.41352
# [84]	valid_0's multi_logloss: 1.34341	valid_0's f1_score: 0.413777
# [85]	valid_0's multi_logloss: 1.34321	valid_0's f1_score: 0.413703
# [86]	valid_0's multi_logloss: 1.34313	valid_0's f1_score: 0.41367
# [87]	valid_0's multi_logloss: 1.34349	valid_0's f1_score: 0.413823
# [88]	valid_0's multi_logloss: 1.34348	valid_0's f1_score: 0.414058
# [89]	valid_0's multi_logloss: 1.34332	valid_0's f1_score: 0.413823
# [90]	valid_0's multi_logloss: 1.34322	valid_0's f1_score: 0.413882
# [91]	valid_0's multi_logloss: 1.34325	valid_0's f1_score: 0.413287
# [92]	valid_0's multi_logloss: 1.34308	valid_0's f1_score: 0.413625
# [93]	valid_0's multi_logloss: 1.34298	valid_0's f1_score: 0.413308
# [94]	valid_0's multi_logloss: 1.34305	valid_0's f1_score: 0.413412
# [95]	valid_0's multi_logloss: 1.34306	valid_0's f1_score: 0.413367
# [96]	valid_0's multi_logloss: 1.34306	valid_0's f1_score: 0.413257
# [97]	valid_0's multi_logloss: 1.34285	valid_0's f1_score: 0.413472
# [98]	valid_0's multi_logloss: 1.3428	valid_0's f1_score: 0.413463
# [99]	valid_0's multi_logloss: 1.34266	valid_0's f1_score: 0.413447
# [100]	valid_0's multi_logloss: 1.3426	valid_0's f1_score: 0.413249
# [101]	valid_0's multi_logloss: 1.34234	valid_0's f1_score: 0.41351
# [102]	valid_0's multi_logloss: 1.34239	valid_0's f1_score: 0.413613
# [103]	valid_0's multi_logloss: 1.34232	valid_0's f1_score: 0.413561
# [104]	valid_0's multi_logloss: 1.34228	valid_0's f1_score: 0.413808
# [105]	valid_0's multi_logloss: 1.34233	valid_0's f1_score: 0.413582
# [106]	valid_0's multi_logloss: 1.34196	valid_0's f1_score: 0.413872
# [107]	valid_0's multi_logloss: 1.34161	valid_0's f1_score: 0.414361
# [108]	valid_0's multi_logloss: 1.34157	valid_0's f1_score: 0.414159
# [109]	valid_0's multi_logloss: 1.34154	valid_0's f1_score: 0.414077
# [110]	valid_0's multi_logloss: 1.34143	valid_0's f1_score: 0.413985
# [111]	valid_0's multi_logloss: 1.34123	valid_0's f1_score: 0.41421
# [112]	valid_0's multi_logloss: 1.34124	valid_0's f1_score: 0.414161
# [113]	valid_0's multi_logloss: 1.34131	valid_0's f1_score: 0.41407
# [114]	valid_0's multi_logloss: 1.34122	valid_0's f1_score: 0.413925
# [115]	valid_0's multi_logloss: 1.34106	valid_0's f1_score: 0.413731
# [116]	valid_0's multi_logloss: 1.34102	valid_0's f1_score: 0.414083
# [117]	valid_0's multi_logloss: 1.34118	valid_0's f1_score: 0.414122
# [118]	valid_0's multi_logloss: 1.3411	valid_0's f1_score: 0.413995
# [119]	valid_0's multi_logloss: 1.34101	valid_0's f1_score: 0.414105
# [120]	valid_0's multi_logloss: 1.34132	valid_0's f1_score: 0.413946
# [121]	valid_0's multi_logloss: 1.34131	valid_0's f1_score: 0.413885
# [122]	valid_0's multi_logloss: 1.34133	valid_0's f1_score: 0.413918
# [123]	valid_0's multi_logloss: 1.34128	valid_0's f1_score: 0.414049
# [124]	valid_0's multi_logloss: 1.34139	valid_0's f1_score: 0.414147
# [125]	valid_0's multi_logloss: 1.34139	valid_0's f1_score: 0.414273
# [126]	valid_0's multi_logloss: 1.34143	valid_0's f1_score: 0.414003
# [127]	valid_0's multi_logloss: 1.34142	valid_0's f1_score: 0.413747
# [128]	valid_0's multi_logloss: 1.34133	valid_0's f1_score: 0.413844
# [129]	valid_0's multi_logloss: 1.34135	valid_0's f1_score: 0.413745
# [130]	valid_0's multi_logloss: 1.3414	valid_0's f1_score: 0.41394
# [131]	valid_0's multi_logloss: 1.34116	valid_0's f1_score: 0.413938
# [132]	valid_0's multi_logloss: 1.3411	valid_0's f1_score: 0.413948
# [133]	valid_0's multi_logloss: 1.34096	valid_0's f1_score: 0.414107
# [134]	valid_0's multi_logloss: 1.3411	valid_0's f1_score: 0.413905
# [135]	valid_0's multi_logloss: 1.34107	valid_0's f1_score: 0.413778
# [136]	valid_0's multi_logloss: 1.34118	valid_0's f1_score: 0.413942
# [137]	valid_0's multi_logloss: 1.34106	valid_0's f1_score: 0.413912
# [138]	valid_0's multi_logloss: 1.34092	valid_0's f1_score: 0.414047
# [139]	valid_0's multi_logloss: 1.34088	valid_0's f1_score: 0.414058
# [140]	valid_0's multi_logloss: 1.34091	valid_0's f1_score: 0.414301
# [141]	valid_0's multi_logloss: 1.34082	valid_0's f1_score: 0.414042
# [142]	valid_0's multi_logloss: 1.34077	valid_0's f1_score: 0.413924
# [143]	valid_0's multi_logloss: 1.34069	valid_0's f1_score: 0.414064
# [144]	valid_0's multi_logloss: 1.34066	valid_0's f1_score: 0.413825
# [145]	valid_0's multi_logloss: 1.34077	valid_0's f1_score: 0.414055
# [146]	valid_0's multi_logloss: 1.34084	valid_0's f1_score: 0.413799
# [147]	valid_0's multi_logloss: 1.34081	valid_0's f1_score: 0.413942
# [148]	valid_0's multi_logloss: 1.34067	valid_0's f1_score: 0.413831
# [149]	valid_0's multi_logloss: 1.34067	valid_0's f1_score: 0.41368
# [150]	valid_0's multi_logloss: 1.34063	valid_0's f1_score: 0.413626
# [151]	valid_0's multi_logloss: 1.3406	valid_0's f1_score: 0.413683
# [152]	valid_0's multi_logloss: 1.34063	valid_0's f1_score: 0.413752
# [153]	valid_0's multi_logloss: 1.34062	valid_0's f1_score: 0.413711
# [154]	valid_0's multi_logloss: 1.34064	valid_0's f1_score: 0.413724
# [155]	valid_0's multi_logloss: 1.34047	valid_0's f1_score: 0.413681
# [156]	valid_0's multi_logloss: 1.34049	valid_0's f1_score: 0.413607
# [157]	valid_0's multi_logloss: 1.34052	valid_0's f1_score: 0.413737
# [158]	valid_0's multi_logloss: 1.34054	valid_0's f1_score: 0.413823
# [159]	valid_0's multi_logloss: 1.34051	valid_0's f1_score: 0.413834
# [160]	valid_0's multi_logloss: 1.34044	valid_0's f1_score: 0.413828
# [161]	valid_0's multi_logloss: 1.34041	valid_0's f1_score: 0.413912
# [162]	valid_0's multi_logloss: 1.34045	valid_0's f1_score: 0.413968
# [163]	valid_0's multi_logloss: 1.34044	valid_0's f1_score: 0.413968
# [164]	valid_0's multi_logloss: 1.3401	valid_0's f1_score: 0.414026
# [165]	valid_0's multi_logloss: 1.34003	valid_0's f1_score: 0.413876
# [166]	valid_0's multi_logloss: 1.33992	valid_0's f1_score: 0.413824
# [167]	valid_0's multi_logloss: 1.33996	valid_0's f1_score: 0.413847
# [168]	valid_0's multi_logloss: 1.33993	valid_0's f1_score: 0.413895
# [169]	valid_0's multi_logloss: 1.33992	valid_0's f1_score: 0.413835
# [170]	valid_0's multi_logloss: 1.33986	valid_0's f1_score: 0.413875
# [171]	valid_0's multi_logloss: 1.33988	valid_0's f1_score: 0.413679
# [172]	valid_0's multi_logloss: 1.33985	valid_0's f1_score: 0.413649
# [173]	valid_0's multi_logloss: 1.33986	valid_0's f1_score: 0.413656
# [174]	valid_0's multi_logloss: 1.33995	valid_0's f1_score: 0.413801
# [175]	valid_0's multi_logloss: 1.33996	valid_0's f1_score: 0.413588
# [176]	valid_0's multi_logloss: 1.33993	valid_0's f1_score: 0.413646
# [177]	valid_0's multi_logloss: 1.3399	valid_0's f1_score: 0.413593
# [178]	valid_0's multi_logloss: 1.3399	valid_0's f1_score: 0.413462
# [179]	valid_0's multi_logloss: 1.33994	valid_0's f1_score: 0.413358
# [180]	valid_0's multi_logloss: 1.33994	valid_0's f1_score: 0.413415
# [181]	valid_0's multi_logloss: 1.34	valid_0's f1_score: 0.41338
# [182]	valid_0's multi_logloss: 1.33999	valid_0's f1_score: 0.41345
# [183]	valid_0's multi_logloss: 1.33997	valid_0's f1_score: 0.413529
# [184]	valid_0's multi_logloss: 1.33995	valid_0's f1_score: 0.413476
# [185]	valid_0's multi_logloss: 1.33996	valid_0's f1_score: 0.413348
# [186]	valid_0's multi_logloss: 1.33992	valid_0's f1_score: 0.413244
# [187]	valid_0's multi_logloss: 1.34008	valid_0's f1_score: 0.413427
# [188]	valid_0's multi_logloss: 1.34005	valid_0's f1_score: 0.413462
# [189]	valid_0's multi_logloss: 1.34003	valid_0's f1_score: 0.413356
# [190]	valid_0's multi_logloss: 1.34003	valid_0's f1_score: 0.413322
# [191]	valid_0's multi_logloss: 1.34002	valid_0's f1_score: 0.413144
# [192]	valid_0's multi_logloss: 1.34004	valid_0's f1_score: 0.413247
# [193]	valid_0's multi_logloss: 1.33995	valid_0's f1_score: 0.413404
# [194]	valid_0's multi_logloss: 1.33996	valid_0's f1_score: 0.413393
# [195]	valid_0's multi_logloss: 1.33992	valid_0's f1_score: 0.413266
# [196]	valid_0's multi_logloss: 1.33989	valid_0's f1_score: 0.413326
# [197]	valid_0's multi_logloss: 1.33983	valid_0's f1_score: 0.413318
# [198]	valid_0's multi_logloss: 1.33981	valid_0's f1_score: 0.413315
# [199]	valid_0's multi_logloss: 1.33983	valid_0's f1_score: 0.413341
# [200]	valid_0's multi_logloss: 1.33984	valid_0's f1_score: 0.413403
# [201]	valid_0's multi_logloss: 1.33988	valid_0's f1_score: 0.413304
# [202]	valid_0's multi_logloss: 1.33988	valid_0's f1_score: 0.41338
# [203]	valid_0's multi_logloss: 1.33985	valid_0's f1_score: 0.41346
# [204]	valid_0's multi_logloss: 1.33987	valid_0's f1_score: 0.413426
# [205]	valid_0's multi_logloss: 1.33985	valid_0's f1_score: 0.413508
# [206]	valid_0's multi_logloss: 1.33987	valid_0's f1_score: 0.413538
# [207]	valid_0's multi_logloss: 1.3399	valid_0's f1_score: 0.413518
# Early stopping, best iteration is:
# [107]	valid_0's multi_logloss: 1.34161	valid_0's f1_score: 0.414361
# 0.41436050871997854

# %%
# submit_df['prediction'] = lgbm.predict(submit_df[new_atrs])

# %%
# submit_df.reset_index()[['client_pin', 'prediction']].to_csv('another_submit.csv', index=False)

# %%
predicts = models[0].predict_proba(submit_df[new_atrs])

# %%
for i in range(1, 5):
    predicts += models[i].predict_proba(submit_df[new_atrs])
# Out:
# (79268, 10)
# (79268, 10)
# (79268, 10)
# (79268, 10)

# %%
submit_df['prediction'] = models[0].classes_[predicts.argmax(axis=-1)]

# %%
submit_df.reset_index()[['client_pin', 'prediction']].to_csv('ensemble.csv', index=False)
